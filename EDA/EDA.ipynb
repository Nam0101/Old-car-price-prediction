# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data
df = pd.read_csv('../data.csv')

# %% [markdown]
# # EDA for old car data

# %%
df.head()
# Out:
#                            car_name  year         price      assemble_place  \
# 0  Kia Sorento Signature 2.2 AT AWD  2020  8.990000e+08  Lắp ráp trong nước
# 1                  Kia Sorento GATH  2018  5.680000e+08  Lắp ráp trong nước
# 2             Mazda CX8 Premium AWD  2022  9.290000e+08  Lắp ráp trong nước
# 3              Nissan Almera 1.0 MT  2022  3.690000e+08           Nhập khẩu
# 4          Bentley Mulsanne 6.75 V8  2011  4.900000e+09           Nhập khẩu
#
#   series     km engine_type transmission  \
# 0    SUV  60000         Dầu   Số tự động
# 1    SUV  80000        Xăng   Số tự động
# 2    SUV  50000        Xăng   Số tự động
# 3  Sedan  25000        Xăng       Số tay
# 4  Sedan  80000        Xăng   Số tự động
#
#                                                  url    brand  \
# 0  https://bonbanh.com/xe-kia-sorento-signature-2...      Kia
# 1  https://bonbanh.com/xe-kia-sorento-gath-2018-5...      Kia
# 2  https://bonbanh.com/xe-mazda-cx8-premium-awd-2...    Mazda
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12529 entries, 0 to 12528
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   car_name        12529 non-null  object
#  1   year            12529 non-null  int64
#  2   price           12529 non-null  float64
#  3   assemble_place  12529 non-null  object
#  4   series          12529 non-null  object
#  5   km              12529 non-null  int64
#  6   engine_type     12529 non-null  object
#  7   transmission    12529 non-null  object
#  8   url             12529 non-null  object
#  9   brand           12529 non-null  object
#  10  model           12527 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#                year         price            km
# count  12529.000000  1.252900e+04  1.252900e+04
# mean    2018.479527  1.163254e+09  9.877953e+04
# std        4.056582  1.651200e+09  2.826858e+06
# min     1990.000000  2.600000e+07  1.000000e+03
# 25%     2017.000000  4.700000e+08  2.800000e+04
# 50%     2020.000000  6.660000e+08  5.000000e+04
# 75%     2021.000000  1.099000e+09  7.800000e+04
# max     2024.000000  4.380000e+10  2.600000e+08

# %%
df.isnull().sum()
# Out:
# car_name          0
# year              0
# price             0
# assemble_place    0
# series            0
# km                0
# engine_type       0
# transmission      0
# url               0
# brand             0
# model             2
# dtype: int64

# %%
threshold = 0.01  # Ngưỡng 5%
df['brand'] = df['brand'].apply(lambda x: 'Other' if df['brand'].value_counts()[x] / len(df) < threshold else x)

# %%
df['brand'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
# biểu đồ giá trị trung bình của từng hãng xe
plt.figure(figsize=(12, 6))
sns.barplot(x='brand', y='price', data=df)
plt.show()

# %%
# biểu đồ giá của xe theo năm sản xuất
plt.figure(figsize=(12, 6))
#loại bỏ xe có tuổi >15
df = df[2024 - df['year']  < 15]
sns.barplot(x='year', y='price', data=df)
plt.show()

# %%
# số lượng xe theo năm sản xuất
plt.figure(figsize=(12, 6))
sns.countplot(x='year', data=df)
plt.show()

# %%
#biểu đồ giá xe theo series
plt.figure(figsize=(12, 6))
sns.barplot(x='series', y='price', data=df)
plt.show()

# %%
# biểu đồ tỉ lệ engine type
df['engine_type'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
# biểu đồ giá xe theo engine type
plt.figure(figsize=(12, 6))
sns.barplot(x='engine_type', y='price', data=df)
plt.show()

# %%
#biểu đồ tỉ lệ transmission
df['transmission'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
# biểu đồ giá xe theo transmission
plt.figure(figsize=(12, 6))
sns.barplot(x='transmission', y='price', data=df)
plt.show()

# %%
# biểu đồ tỉ lệ nơi sản xuất
df['assemble_place'].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
# biểu đồ giá xe theo nơi sản xuất
plt.figure(figsize=(12, 6))
sns.barplot(x='assemble_place', y='price', data=df)
plt.show()
